# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import gzip 
EL = pd.read_csv('../code/ebpmf_models/filtered/snmf_10/tables/transcript.EL.bed.gz', sep='\t')
samples = pd.read_csv('../data/sample.tsv', sep='\t')
samples_list = EL.columns[6:]
samples = samples.set_index('entity:sample_id')

# %%
EL = EL.set_index('pid')

# %%
tpm_fh = gzip.open('../code/gtex_tables/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz', 'r')
tpm_fh.readline()
tpm_fh.readline()
tpm_columns = tpm_fh.readline().decode().rstrip().split('\t')

syngr1 = 'ENSG00000100321'
for linea in tpm_fh:
    linea = linea.decode().rstrip().split('\t')
    if linea[0].startswith(syngr1):
        break

# %%
tissues = sorted(['Brain_Anterior_cingulate_cortex_BA24',
 'Brain_Cortex',
 'Brain_Frontal_Cortex_BA9',
 'Brain_Putamen_basal_ganglia',
           'Skin_Not_Sun_Exposed_Suprapubic',
           'Liver',
 'Lung', 'Heart_Atrial_Appendage', 'Muscle_Skeletal','Whole_Blood'
          ])
wb_samples = samples.loc[samples.tissue_id.isin(tissues)].index.intersection(EL.columns)
tpm_wb_samples = [x in wb_samples for x in tpm_columns]

pkm_tpm_wb = [float(x) for x in np.array(linea)[tpm_wb_samples]]

tpm_wb_order = []
for i, idx in enumerate(tpm_wb_samples):
    if idx:
        tpm_wb_order.append(tpm_columns[i])

# %%
plt.scatter(np.log1p(pkm_tpm_wb), 
            np.array(EL.loc[['ENSG00000100321.isoform_5'], tpm_wb_order]) + np.array(EL.loc[['ENSG00000100321.isoform_4'], tpm_wb_order]) + np.array(EL.loc[['ENSG00000100321.isoform_3'], tpm_wb_order]))

# %%
qqnorm_ba24 = pd.read_csv('../code/gtex_tables/GTEx_Analysis_v8_eQTL_expression_matrices/Brain_Anterior_cingulate_cortex_BA24.v8.normalized_expression.bed.gz',
                          sep='\t')
qqnorm_ba24.index = qqnorm_ba24.gene_id.apply(lambda x: x.split('.')[0])

# %%
samples.loc[samples.tissue_id == 'Brain_Anterior_cingulate_cortex_BA24'].participant.unique()
# Out:
# array(['GTEX-11DXW', 'GTEX-11DZ1', 'GTEX-11GSO', 'GTEX-11GSP',
#        'GTEX-11UD1', 'GTEX-11WQC', 'GTEX-11WQK', 'GTEX-11ZTS',
#        'GTEX-11ZVC', 'GTEX-12WSC', 'GTEX-12WSD', 'GTEX-12WSF',
#        'GTEX-12WSM', 'GTEX-12ZZW', 'GTEX-12ZZX', 'GTEX-12ZZZ',
#        'GTEX-13112', 'GTEX-1313W', 'GTEX-131XH', 'GTEX-131YS',
#        'GTEX-139T8', 'GTEX-139TT', 'GTEX-13CF2', 'GTEX-13CIG',
#        'GTEX-13CZV', 'GTEX-13FHO', 'GTEX-13FLV', 'GTEX-13IVO',
#        'GTEX-13JVG', 'GTEX-13N1W', 'GTEX-13N2G', 'GTEX-13NYB',
#        'GTEX-13NYS', 'GTEX-13O3O', 'GTEX-13O3Q', 'GTEX-13OVH',
#        'GTEX-13OVL', 'GTEX-13OW5', 'GTEX-13OW7', 'GTEX-13OW8',
#        'GTEX-13PLJ', 'GTEX-13PVQ', 'GTEX-13QIC', 'GTEX-13RTJ',
#        'GTEX-13RTL', 'GTEX-13S7M', 'GTEX-13SLW', 'GTEX-13VXU',
#        'GTEX-13X6I', 'GTEX-13X6J', 'GTEX-13X6K', 'GTEX-1445S',
#        'GTEX-144GL', 'GTEX-145LS', 'GTEX-145LU', 'GTEX-145MG',
#        'GTEX-145MH', 'GTEX-1477Z', 'GTEX-148VJ', 'GTEX-14BIM',
#        'GTEX-14BIN', 'GTEX-14BMV', 'GTEX-14C39', 'GTEX-14DAQ',
#        'GTEX-14E7W', 'GTEX-14JG1', 'GTEX-14JIY', 'GTEX-14LLW',
#        'GTEX-14LZ3', 'GTEX-14PJM', 'GTEX-14PJO', 'GTEX-14PN4',
#        'GTEX-14PQA', 'GTEX-15CHQ', 'GTEX-15DCD', 'GTEX-15DYW',
#        'GTEX-15EO6', 'GTEX-15ER7', 'GTEX-15G19', 'GTEX-15SHU',
#        'GTEX-16XZZ', 'GTEX-16YQH', 'GTEX-17EVP', 'GTEX-17EVQ',
#        'GTEX-17F97', 'GTEX-17HHY', 'GTEX-17HII', 'GTEX-18A6Q',
#        'GTEX-1A3MX', 'GTEX-1B8L1', 'GTEX-1B933', 'GTEX-1B996',
#        'GTEX-1BAJH', 'GTEX-1C6WA', 'GTEX-1CB4G', 'GTEX-1CB4H',
#        'GTEX-1E1VI', 'GTEX-1EH9U', 'GTEX-1EMGI', 'GTEX-1EN7A',
#        'GTEX-1EU9M', 'GTEX-1EX96', 'GTEX-1F48J', 'GTEX-1F52S',
#        'GTEX-1F6I4', 'GTEX-1F75A', 'GTEX-1F7RK', 'GTEX-1GF9W',
#        'GTEX-1GMR8', 'GTEX-1GN73', 'GTEX-1GTWX', 'GTEX-1GZ2Q',
#        'GTEX-1GZ4I', 'GTEX-1H1ZS', 'GTEX-1H23P', 'GTEX-1H2FU',
#        'GTEX-1H3O1', 'GTEX-1H3VE', 'GTEX-1HB9E', 'GTEX-1HBPH',
#        'GTEX-1HCU6', 'GTEX-1HFI6', 'GTEX-1HGF4', 'GTEX-1HR98',
#        'GTEX-1HUB1', 'GTEX-1I1GR', 'GTEX-1I1GS', 'GTEX-1I1GV',
#        'GTEX-1IDJH', 'GTEX-1IKJJ', 'GTEX-1IKK5', 'GTEX-1J1OQ',
#        'GTEX-1J8EW', 'GTEX-1J8Q2', 'GTEX-1JJEA', 'GTEX-1JMOU',
#        'GTEX-1JMPZ', 'GTEX-1KD4Q', 'GTEX-1LVAO', 'GTEX-1MCQQ',
#        'GTEX-1N2EE', 'GTEX-N7MS', 'GTEX-N7MT', 'GTEX-NL3H', 'GTEX-NPJ8',
#        'GTEX-P44G', 'GTEX-P44H', 'GTEX-PVOW', 'GTEX-PWO3', 'GTEX-Q2AG',
#        'GTEX-QDT8', 'GTEX-QVUS', 'GTEX-RNOR', 'GTEX-RVPV', 'GTEX-T2IS',
#        'GTEX-UTHO', 'GTEX-WHSE', 'GTEX-WL46', 'GTEX-WZTO', 'GTEX-X4EP',
#        'GTEX-X4XX', 'GTEX-X4XY', 'GTEX-X585', 'GTEX-XLM4', 'GTEX-XMD1',
#        'GTEX-Y8DK', 'GTEX-YFC4', 'GTEX-YJ89', 'GTEX-Z93S', 'GTEX-ZAB4',
#        'GTEX-ZDXO', 'GTEX-ZE9C', 'GTEX-ZF28', 'GTEX-ZUA1', 'GTEX-ZVT3',
#        'GTEX-ZVZQ'], dtype=object)

# %%
qqnorm_ba24
# Out:
#                  #chr      start        end             gene_id  GTEX-11DZ1  \
# gene_id
# ENSG00000227232  chr1      29552      29553   ENSG00000227232.5    0.363520
# ENSG00000186092  chr1      69090      69091   ENSG00000186092.4   -0.906134
# ENSG00000268903  chr1     135894     135895   ENSG00000268903.1    0.455640
